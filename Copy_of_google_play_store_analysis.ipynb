# %% [markdown]
# <a href="https://colab.research.google.com/github/Yogitha-1224/google-play-store-data-analysis-python/blob/main/Copy_of_google_play_store_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Pandas--Google play store app analysis
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
#Load the content of csv file Google play Store
df=pd.read_csv("/content/googleplaystore.csv")
print(df)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# Find Total Number Apps in Google Play Store
print("Total Number Apps in Google Play Store=",df['App'].count())
# Out:
# Total Number Apps in Google Play Store= 10841

# %%
# Find the Total Number of Columns in Each app of Google Play Store
print("Total Number of Columns in Each app of Google Play Store=",df.shape[1])
# Out:
# Total Number of Columns in Each app of Google Play Store= 13

# %%
# Display Top 5 Rows of The Dataset
top5rows=df.head()
print("------------------------------------")
print("Top 5 Rows of The Dataset")
print("------------------------------------")
print(top5rows)
print("------------------------------------")
# Out:
# ------------------------------------
# Top 5 Rows of The Dataset
# ------------------------------------
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
# ...

# %%
#Check the Last 3 Rows of The Dataset
import pandas as pd
df=pd.read_csv("/content/googleplaystore.csv")
print(df)
last3rows=df.tail(3)
print("------------------------------------")
print("Last 3 Rows of The Dataset")
print("------------------------------------")
print(last3rows)
print("------------------------------------")
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#Find shape of our Dataset (Number of Rows and Columns)
print("Shape of Our Dataset = ",df.shape)
print(df.shape)
# Out:
# Shape of Our Dataset =  (10841, 13)
# (10841, 13)

# %%
#Get information about our dataset like Total number Rows ,Total number columns , datatypes of each column and memory Requirement
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
#get overall statistics about the dataframe
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
#Print all the columns present in the dataset
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
#Obatin Total number of apps whose title contain ART_AND_DESIGN
len(df[(df["App"].str.contains("Art_And_Design"))])
# Out:
# 0

# %%
#Obatin Total number of apps whose title contain Family
len(df[(df["App"].str.contains("Family"))])
# Out:
# 25

# %%
#Print the App name related to the Family
for appname in df[(df["App"].str.contains("Family"))]["App"].values:
 print(appname)
# Out:
# FamilySearch Tree
# Family Locator - GPS Tracker
# Family convenience store FamilyMart
# SweetLand — Family Board Game
# Familyfirst Messenger
# Phone Tracker : Family Locator
# Family GPS tracker KidControl + GPS by SMS Locator
# Family Dollar
# Cozi Family Organizer
# Family Album Mitene: Private Photo & Video Sharing
# Family GPS Tracker and Chat + Baby Monitor Online
# Safe365 – Cell Phone GPS Locator For Your Family
# Dog Sim Online: Raise a Family
# AT&T FamilyMap®
# T-Mobile® FamilyMode™
# BF Family user
# Brilliant Quotes: Life, Love, Family & Motivation
# CR Family
# Family Savings CU Mobile
# Phone Tracker : Family Locator
# Eat Right Diet (by Dt Shreya's Family Diet Clinic)
# Ludo Family Dice Game
# Mom Doctor ER Emergency Family Game
# Family Guy The Quest for Stuff
# Family Guy- Another Freakin' Mobile Game

# %%
#Find average app rating in Google play store
df['Rating'].mean()
# Out:
# np.float64(4.193338315362443)

# %%
#Find Total Number of nunique Category Apps
df['Category'].nunique()
# Out:
# 34

# %%
#Find Total Unique Category Apps names
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
# Which category getting the highest average rating
df.groupby('Category')['Rating'].mean().sort_values(ascending=False)
# Out:
# Category
# 1.9                    19.000000
# EVENTS                  4.435556
# EDUCATION               4.389032
# ART_AND_DESIGN          4.358065
# BOOKS_AND_REFERENCE     4.346067
# PERSONALIZATION         4.335987
# PARENTING               4.300000
# GAME                    4.286326
# BEAUTY                  4.278571
# HEALTH_AND_FITNESS      4.277104
# SHOPPING                4.259664
# SOCIAL                  4.255598
# WEATHER                 4.244000
# SPORTS                  4.223511
# PRODUCTIVITY            4.211396
# HOUSE_AND_HOME          4.197368
# FAMILY                  4.192272
# PHOTOGRAPHY             4.192114
# AUTO_AND_VEHICLES       4.190411
# MEDICAL                 4.189143
# LIBRARIES_AND_DEMO      4.178462
# FOOD_AND_DRINK          4.166972
# COMMUNICATION           4.158537
# COMICS                  4.155172
# NEWS_AND_MAGAZINES      4.132189
# FINANCE                 4.131889
# ENTERTAINMENT           4.126174
# BUSINESS                4.121452
# ...

# %%
# Find Total Number of Apps having 5 Star Rating
df[df['Rating'] == 5]['Rating'].count()
# Out:
# np.int64(274)

# %%
df[df['Rating'] ==5.0]
# Out:
#                                               App   Category  Rating Reviews  \
# 329                  Hojiboy Tojiboyev Life Hacks     COMICS     5.0      15
# 612                 American Girls Mobile Numbers     DATING     5.0       5
# 615                                  Awake Dating     DATING     5.0       2
# 633                         Spine- The dating app     DATING     5.0       5
# 636    Girls Live Talk - Free Text and Video Chat     DATING     5.0       6
# ...                                           ...        ...     ...     ...
# 10721                           Mad Dash Fo' Cash       GAME     5.0      14
# 10742                       GKPB FP Online Church  LIFESTYLE     5.0      32
# 10776                            Monster Ride Pro       GAME     5.0       1
# 10820                             Fr. Daoud Lamei     FAMILY     5.0      22
# 10837            Fr. Mike Schmitz Audio Teachings     FAMILY     5.0       4
#
# ...

# %%
# Find Total number of Free and Paid Apps
df["Type"]
# Out:
# 0        Free
# 1        Free
# 2        Free
# 3        Free
# 4        Free
#          ...
# 10836    Free
# 10837    Free
# 10838    Free
# 10839    Free
# 10840    Free
# Name: Type, Length: 10841, dtype: object

# %%
# Find Total number of Free Apps
print("Number of Free Apps=",len(df[df["Type"]=="Free"]))
# Out:
# Number of Free Apps= 10039

# %%
# Find Total number of Paid Apps
print("Number of Paid Apps=",len(df[df["Type"]=="Paid"]))
# Out:
# Number of Paid Apps= 800

# %%
# Display Top 5 apps having maximum installs
df.columns
df.groupby('App').sum()['Installs'].sort_values(ascending=False).head(5)
# Out:
# App
# Life Made WI-Fi Touchscreen Photo Frame                                                 Free
# Candy Crush Saga                           500,000,000+500,000,000+500,000,000+500,000,00...
# Temple Run 2                               500,000,000+500,000,000+500,000,000+500,000,00...
# Viber Messenger                            500,000,000+500,000,000+500,000,000+500,000,00...
# Snapchat                                    500,000,000+500,000,000+500,000,000+500,000,000+
# Name: Installs, dtype: object
